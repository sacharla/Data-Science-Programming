# %% [markdown]
# # ICP11 - Autoencoder

# %%
import numpy as np

# %% [markdown]
# ### Load and normalize our data

# %%
from tensorflow.keras.datasets import mnist


# load MNIST data
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
print(train_images.shape)
print(test_images.shape)

# Flatten the images for a autoencoder input (28x28 is 784 -- therfore, input is 784 neurons)
train_images = np.reshape(train_images, (-1, 784))
test_images = np.reshape(test_images, (-1, 784))
print(train_images.shape)
print(test_images.shape)

# Normalize data - since it's grayscale, we can divide by 255 to get each pixel between 0 and 1
train_images = train_images.astype('float32') / 255
test_images = test_images.astype('float32') / 255
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# (60000, 784)
# (10000, 784)

# %%
from matplotlib import pyplot as plt

n = 10
plt.figure(figsize=(9, 2))
for i in range(n):
  ax = plt.subplot(1, n, i+1)
  plt.imshow(test_images[i].reshape(28, 28), cmap="gray")
  ax.axis('off')

plt.show()

# %% [markdown]
# ### Create an autoencoder model.

# %%
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

input_dim = 28*28
latent_vec_len = 6 # update the bottleneck layer to six neurons

# Define the autoencoder architecture
# build the encoder
autoencoder = Sequential()
autoencoder.add(Input(shape=(input_dim,)))
autoencoder.add(Dense(500, activation='relu'))
autoencoder.add(Dense(300, activation='relu'))
autoencoder.add(Dense(100, activation='relu'))

# the bottleneck layer
autoencoder.add(Dense(latent_vec_len, activation='relu'))

# the decoder layer
autoencoder.add(Dense(100, activation='relu'))
autoencoder.add(Dense(300, activation='relu'))
autoencoder.add(Dense(500, activation='relu'))
autoencoder.add(Dense(input_dim, activation='sigmoid'))

# Compile the autoencoder model
autoencoder.compile(loss='binary_crossentropy', optimizer='adam')

# Get summary
autoencoder.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 500)               392500
#
#  dense_1 (Dense)             (None, 300)               150300
#
#  dense_2 (Dense)             (None, 100)               30100
#
#  dense_3 (Dense)             (None, 6)                 606
#
#  dense_4 (Dense)             (None, 100)               700
#
#  dense_5 (Dense)             (None, 300)               30300
#
#  dense_6 (Dense)             (None, 500)               150500
#
#  dense_7 (Dense)             (None, 784)               392784
#
# =================================================================
# Total params: 1,147,790
# Trainable params: 1,147,790
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the autoencoder model.

# %%
from tensorflow.keras.callbacks import EarlyStopping # EarlyStopping during model training


# Train the autoencoder with MNIST data
early_stop = EarlyStopping(monitor='loss', patience=3, verbose=1)
history = autoencoder.fit(
    x=train_images, # For autoencoders, both the input and the target are the same
    y=train_images, 
    epochs=10, 
    batch_size=128,
    shuffle=True, 
    validation_data=(test_images, test_images),
    callbacks=[early_stop]
)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 9s 17ms/step - loss: 0.2030 - val_loss: 0.1582
# Epoch 2/10
# 469/469 [==============================] - 7s 16ms/step - loss: 0.1524 - val_loss: 0.1483
# Epoch 3/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.1453 - val_loss: 0.1428
# Epoch 4/10
# 469/469 [==============================] - 7s 16ms/step - loss: 0.1412 - val_loss: 0.1398
# Epoch 5/10
# 469/469 [==============================] - 8s 16ms/step - loss: 0.1382 - val_loss: 0.1371
# Epoch 6/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.1359 - val_loss: 0.1356
# Epoch 7/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.1340 - val_loss: 0.1339
# Epoch 8/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.1322 - val_loss: 0.1326
# Epoch 9/10
# 469/469 [==============================] - 8s 18ms/step - loss: 0.1308 - val_loss: 0.1313
# Epoch 10/10
# 469/469 [==============================] - 8s 17ms/step - loss: 0.1279 - val_loss: 0.1276

# %%
# Plot training and validation loss scores
# against the number of epochs.
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.ylabel('Binary Cross Entropy Loss')
plt.xlabel('Epoch')
plt.title('Autoencoder Reconstruction Loss', pad=13)
plt.legend(loc='upper right')

# %% [markdown]
# ### Test the autoencoder model by reconstructing the test images and visually inspecting the results.

# %%
reconstructed_images = autoencoder.predict(test_images)

images = []
for i in range(100):
    images.append(test_images[i].reshape(28,28))
    images.append(reconstructed_images[i].reshape(28,28))
rows = 10
cols = 10
plt.figure(figsize=(10,10))
for i in range(rows*cols):
    plt.subplot(rows,cols,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    if (i%2 == 0):
        plt.imshow(images[i],cmap='gray')
    else:
        plt.imshow(images[i])
plt.show()
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# ### Save the autoencoder for later user.

# %%
autoencoder.save('Downloads/initially_trained_autoencoder.h5')

# %% [markdown]
# But what happens if we sent it something it has been trained on? Let’s try it out:

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image


####################################
# load a sample image
image = tf.keras.utils.load_img('Downloads/testimg02.png', target_size=(28, 28), color_mode = "grayscale")


####################################
# predict an image from this sample
input_arr = tf.keras.utils.img_to_array(image)
input_arr = input_arr/ 255 # normalize between 0 and 1
input_arr = input_arr.reshape(784)
input_arr = np.array([input_arr])  # Convert single image to a batch with one image in it

predictions = autoencoder.predict(input_arr)
print(predictions.shape)


#####################################
# display the two images side by side
# 
plt.subplot(1,2,1)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.imshow(image, cmap="gray")


plt.subplot(1,2,2)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.imshow(predictions[0].reshape(28,28), cmap="gray")


plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [10], in <cell line: 7>()
#       2 from tensorflow.keras.preprocessing import image
#       5 ####################################
#       6 # load a sample image
# ----> 7 image = tf.keras.utils.load_img('Downloads/testimg02.png', target_size=(28, 28), color_mode = "grayscale")
#      10 ####################################
#      11 # predict an image from this sample
#      12 input_arr = tf.keras.utils.img_to_array(image)
#
# File ~\anaconda3\lib\site-packages\keras\utils\image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Downloads/testimg02.png'

# %% [markdown]
# ## Inference:
#
# Initially, by changing the value of the bottleneck layer from 16 to 6 neurons, I see the loss factor has increased from 0.0995 to 0.1279 for the lower values of the epoch. This means that with the reduction in the number of bottleneck layers, we see the model extracting limited amount of information from the input data. This has resulted high loss factor.
#
# Based on my analysis, it seems that the model with 100 neurons in the bottleneck layer is the best-performing model among the three models, as it has the lowest loss values. However, it's important to keep in mind that a larger number of neurons in the bottleneck layer would make the model more complex and require more computational resources to train.
#
# When determining the optimal number of neurons to use in the bottleneck layer of an autoencoder model, several factors should be taken into consideration, such as the complexity of the input data, the desired level of compression, and the available computational resources. In general, starting with a moderate number of neurons and experimenting with increasing or decreasing the size could help find the optimal balance between model complexity and performance. It's important to note that the number of neurons in the bottleneck layer may vary widely depending on the specific application and the nature of the input data.
