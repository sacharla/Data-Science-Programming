# %% [markdown]
# # ICP01 Jupyter Install
#
#
#
# ## Srinidhi Acharla

# %% [markdown]
# Picture:
#
# ![srinidhi.jpg](attachment:srinidhi.jpg)
#
#
# Introduction:
#
# This is Srinidhi Acharla and I am a graduate student pursuing my Masters in the Business Analytics and information systems from the University of South Florida. I have a total work experience of four years as a Software Developer and a Product support engineer and my goal here was to specifically develop functions, adding control flow logic, running scripts in CI/CD pipeline, administrating cloud, VMware environments, validating software bugs, providing patches and actively involved in integration and testing of the applications. Through this course, I would like to gain exposure into the Data Science and the Business Analytics fields by engaging into more of the practical projects that can not only add to my resume but also kickstart my career in the Data Science field, as I aspire to enter into this field.

# %%
#Print Hello World

print("Hello, World!")
# Out:
# Hello, World!
